# %% [markdown]
# Create a python class called WeatherStation with the following;
# 1. Attributes :
#         - name - name of the station
#         - location - city/country
#
# 2. Method:
#         - report_weather(temp) - returns a sentence like: "station nairobi reports 22^c"
#
# 3. create an object from the class and call the method

# %%
class WeatherStation ():
    def __init__ (self, name, location):
        self.name = name 
        self.location = location 

    def report_weather(self, temp):
        return f"Station {self.name} at {self.location} reports a temperature of {temp}°C."
    
WeatherStation1 = WeatherStation("Central Park", "New York")
print(WeatherStation1.report_weather(22))
# Out:
# Station Central Park at New York reports a temperature of 22°C.

# %%
! pip install fastapi uvicorn
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 390.1 kB/s eta 0:00:001m841.4 kB/s eta 0:00:01
# ...
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# ...
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.2/109.2 kB 722.4 kB/s eta 0:00:0031m10.7 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.1/68.1 kB 532.8 kB/s eta 0:00:00B/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.3/108.3 kB 582.1 kB/s eta 0:00:0031m6.4 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 463.4/463.4 kB 1.4 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 2.5 MB/s eta 0:00:00m eta 0:00:010:01:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.3/74.3 kB 598.2 kB/s eta 0:00:001m19.8 MB/s eta 0:00:01
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# ...

# %%
from fastapi import FastAPI

app = FastAPI()

@app.get("/info")
def get_info():
    return {"Name":"Erick Wambugu",
            "Mission":"Become a Backend Developer",
            "station": WeatherStation1.name, 
            "location": WeatherStation1.location}
